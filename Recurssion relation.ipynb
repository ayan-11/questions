# %% [raw]
# 1. Find the value of T(2) for the recurrence relation T(n) = 3T(n-1) + 12n, given that T(0)=5.

# %% [raw]
# To find the value of \( T(2) \) for the recurrence relation \( T(n) = 3T(n-1) + 12n \) with the initial condition \( T(0) = 5 \), we can follow these steps:
#
# 1. Calculate ( T(1) ) using ( T(0) ).
# 2. Calculate ( T(2) ) using ( T(1) ).
#
# First, let's calculate ( T(1)):
# T(1) = 3T(0) + 12.1
#
# Substitute ( T(0) = 5 ):
#
# T(1) = 3.5 + 12 = 15 + 12 = 27
#
# Next, calculate ( T(2) ):
#
# T(2) = 3T(1) + 12.2 ]
#
# Substitute ( T(1) = 27):
#
# T(2) = 3.27 + 24 = 81 + 24 = 105
#
# So, the value of ( T(2) ) is ( 105 ).

# %% [raw]
# 2. Given a recurrence relation, solve it using the substitution method:
# a. T(n) = T(n-1) + c
# b. T(n) = 2T(n/2) + n
# c. T(n) = 2T(n/2) + c
# d. T(n) = T(n/2) + c

# %% [raw]
# Let's solve each recurrence relation using the substitution method.
#
# a. T(n) = T(n-1) + c
#
# This is a simple linear recurrence. We will solve it by expanding the recurrence.
#
# T(n) = T(n-1) + c
#      = (T(n-2) + c) + c
#      = T(n-2) + 2c
#      = .....
#      = T(n-k) + kc
#
# Setting ( k = n ):
#
# T(n) = T(0) + nc
#
# So, the solution is: T(n) = T(0) + nc
#
# b. T(n) = 2T(n/2) + n
#
# This is a divide-and-conquer recurrence, which we will solve using the recursion tree method or the Master Theorem. Here, we will use the Master Theorem.
#
# The recurrence b. T(n) = 2T(n/2) + n fits the form (T(n) = aT(n/b) + f(n), where ( a = 2), ( b = 2), and ( f(n) = n).
#
# Using the Master Theorem:
#
# 1. ( a = 2 )
# 2. ( b = 2)
# 3. ( f(n) = n )
# 4. ( log_b a = log_2 2 = 1)
#
# Since ( f(n) = n =Theta(n^c)) where ( c = 1 ), we compare ( c ) with ( log_b a ):
#
# - If ( f(n) = Theta(n^{log_b a}) ), then ( T(n) = Theta(n^{log_b a} log n) ).
#
# Here, ( c =log_b a ), so: T(n) = Theta(n log n)
#
# c. T(n) = 2T(n/2) + c
#
# This is another divide-and-conquer recurrence. We'll use the Master Theorem again.
#
# The recurrence ( T(n) = 2T(n/2) + c ) fits the form ( T(n) = aT(n/b) + f(n) ), where ( a = 2 ), ( b = 2 ), and ( f(n) = c ) (a constant).
#
# Using the Master Theorem:
#
# 1. ( a = 2 )
# 2. ( b = 2 )
# 3. ( f(n) = c = Theta(1) )
# 4. ( log_b a = log_2 2 = 1 )
#
# Since ( f(n) = Theta(n^0) ) and ( log_b a = 1 ):
#
# - If ( f(n) = O(n^c) ) where ( c < log_b a ), then ( T(n) = Theta(n^{log_b a}) ).
#
# Here, ( 0 < 1 ): T(n) = Theta(n)
#
# d. T(n) = T(n/2) + c
#
# This recurrence is simpler than the previous ones. We solve it using the iterative method.
#
# T(n) = T(n/2) + c
#      = (T(n/4) + c) + c
#      = T(n/4) + 2c
#      = (T(n/8) + c) + 2c
#      = T(n/8) + 3c
#      = .....
#      = T(n/2^k) + kc
#
#
# Setting ( n/2^k = 1 ):
# n = 2^k implies k = log_2 n
#
# Substitute ( k = log_2 n ):
# T(n) = T(1) + c \log_2 n
#
# Assuming ( T(1) ) is a constant ( T_0 ):
# T(n) = T_0 + c \log_2 n
#
# So, the solution is: T(n) = Theta(\log n)

# %% [raw]
# 3. Given a rec%rrence relation, solve it %sing the rec%rsive tree approach:
# a. T(n) = 2T(n-1) +1
# b. T(n) = 2T(n/2) + n

# %% [raw]
# a. T(n) = 2T(n-1) +1
#
# - Tree Depth: ( n )
# - Cost per Level: ( 1, 2, 4,......, 2^{n-1} )
# - Total Cost: ( 2^n - 1 )
#
# Solution: ({O}(2^n))
#
# b. T(n) = 2T(n/2) + n
#
# - Tree Depth: (log_2{n})
# - Cost per Level: ( n )
# - Total Cost: ( n log_2{n} )
#
# Solution: ({O}(nlog n))
